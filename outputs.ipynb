# %% [markdown]
# Formula 1: NGDP ~ year + revtq + invtq + oibdpq + ppentq + xrdq
#
# RMSE on Predictors: 10.7262427622723
#
# ```R-squared:                       0.385
# Adj. R-squared:                  0.347
# F-statistic:                     10.03
# Prob (F-statistic):           1.39e-08
# Log-Likelihood:                -223.15
# AIC:                             460.3
# BIC:                             478.7
# Covariance Type:            nonrobust
# ======================================================
#                  coef    std err          t      P>|t|
# ------------------------------------------------------
# Intercept   -565.9451    342.190     -1.654      0.101
# year           0.2887      0.172      1.675      0.097
# revtq      -9.488e-07   1.18e-06     -0.805      0.423
# invtq      -2.044e-06   5.62e-07     -3.638      0.000
# oibdpq      1.857e-05    3.4e-06      5.467      0.000
# ppentq     -1.713e-06   4.58e-07     -3.740      0.000
# xrdq       -6.027e-06   1.18e-05     -0.510      0.611
# ======================================================
# Omnibus:        0.796   Durbin-Watson:           1.570
# Prob(Omnibus):  0.672   Jarque-Bera (JB):        0.891
# Skew:          -0.120   Prob(JB):                0.641
# Kurtosis:       2.613   Cond. No.             1.52e+10
# ======================================================
# ```
#
# Formula 2: NGDP ~ year + revtq_lag + invtq_lag + oibdpq_lag + ppentq_lag + xrdq_lag
#
# RMSE on Predictor Lags: 11.099918823245151
#
# ```R-squared:                       0.265
# Adj. R-squared:                  0.219
# F-statistic:                     5.757
# Prob (F-statistic):           3.76e-05
# Log-Likelihood:                -232.39
# AIC:                             478.8
# BIC:                             497.2
# Covariance Type:            nonrobust
# ======================================================
#                  coef    std err          t      P>|t|
# ------------------------------------------------------
# Intercept  -1194.5296    399.182     -2.992      0.004
# year           0.6054      0.201      3.011      0.003
# revtq_lag  -1.783e-06   1.34e-06     -1.331      0.186
# invtq_lag  -1.649e-06   6.07e-07     -2.714      0.008
# oibdpq_lag  1.424e-05   3.71e-06      3.832      0.000
# ppentq_lag  -1.69e-06   5.01e-07     -3.374      0.001
# xrdq_lag   -5.097e-06   1.28e-05     -0.399      0.690
# ======================================================
# Omnibus:       10.680   Durbin-Watson:           1.627
# Prob(Omnibus):  0.005   Jarque-Bera (JB):       14.294
# Skew:          -0.516   Prob(JB):             0.000787
# Kurtosis:       4.506   Cond. No.             1.61e+10
# ======================================================
# ```
#
# Formula 3: NGDP ~ year + revtq_growth + invtq_growth + oibdpq_growth + ppentq_growth + xrdq_growth
#
# RMSE on Predictor Growths: 11.092666572821239
#
# ```R-squared:                       0.186
# Adj. R-squared:                  0.135
# F-statistic:                     3.647
# Prob (F-statistic):            0.00264
# Log-Likelihood:                -237.64
# AIC:                             489.3
# BIC:                             507.7
# Covariance Type:            nonrobust
# =========================================================
#                     coef    std err          t      P>|t|
# ---------------------------------------------------------
# Intercept       197.1212     70.725      2.787      0.006
# year             -0.0962      0.035     -2.724      0.008
# revtq_growth      2.9307      5.157      0.568      0.571
# invtq_growth      9.3794      6.402      1.465      0.146
# oibdpq_growth     6.3310      3.547      1.785      0.077
# ppentq_growth   -12.7035      9.168     -1.386      0.169
# xrdq_growth      -0.8825      0.492     -1.795      0.076
# =========================================================
# Omnibus:          18.901   Durbin-Watson:           1.431
# Prob(Omnibus):     0.000   Jarque-Bera (JB):       27.458
# Skew:             -0.858   Prob(JB):             1.09e-06
# Kurtosis:          4.858   Cond. No.             5.71e+05
# =========================================================
# ```
#
# Formula 4: NGDP ~ year + revtq_growth_lag + invtq_growth_lag + oibdpq_growth_lag + ppentq_growth_lag + xrdq_growth_lag
#
# RMSE on Predictor Growth Lags: 10.83308909755563
#
# ```R-squared:                       0.226
# Adj. R-squared:                  0.177
# F-statistic:                     4.668
# Prob (F-statistic):           0.000331
# Log-Likelihood:                -235.03
# AIC:                             484.1
# BIC:                             502.5
# Covariance Type:            nonrobust
# =============================================================
#                         coef    std err          t      P>|t|
# -------------------------------------------------------------
# Intercept           174.0474     69.461      2.506      0.014
# year                 -0.0847      0.035     -2.442      0.016
# revtq_growth_lag      0.2222      4.065      0.055      0.957
# invtq_growth_lag     21.3640      6.103      3.500      0.001
# oibdpq_growth_lag     0.7149      2.716      0.263      0.793
# ppentq_growth_lag    -5.6208      1.731     -3.246      0.002
# xrdq_growth_lag      -1.2360      0.471     -2.622      0.010
# =============================================================
# Omnibus:              10.719   Durbin-Watson:           1.476
# Prob(Omnibus):         0.005   Jarque-Bera (JB):       12.029
# Skew:                 -0.613   Prob(JB):              0.00244
# Kurtosis:              4.140   Cond. No.             5.75e+05
# =============================================================
# ```
